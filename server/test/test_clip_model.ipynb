# %%
# %load ~/.firstcell.py
# %load_ext autoreload
# %autoreload 2

import json
import numpy as np 
from PIL import Image
import cv2
import os 
import sys
import csv
from IPython.display import Video, HTML
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import model_utils

# %%
image = Image.open('pug.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800 at 0x7F7D15766820>

# %%
labels = ['puppy', 'tree']

# %%
model = model_utils.CLIPModel()
label_scores = model.inference(image, labels)

# %%
label_scores
# Out:
# array([0.594 , 0.4058], dtype=float16)
